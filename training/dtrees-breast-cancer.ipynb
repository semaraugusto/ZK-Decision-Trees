# %%
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from IPython.display import Image 
from pydot import graph_from_dot_data
import pandas as pd
import numpy as np
from io import StringIO

# %%
dataset = load_breast_cancer()
X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
y = pd.Categorical.from_codes(dataset.target, dataset.target_names)

# %%
y = pd.get_dummies(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
tree = DecisionTreeClassifier()

tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data, feature_names=dataset.feature_names)
(graph, ) = graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
def encode_tree(tree):
    print(tree.feature) 
    print(tree.threshold)
    print(len(tree.feature))
    print(len(tree.threshold))

encode_tree(tree.tree_)
# Out:
# [ 7 20 10 24 14 27 -2 -2 21 -2 21 -2 -2 -2 16 -2 -2 21 -2 17 -2 -2 21 22
#  -2 -2 23 21 -2 -2 -2]
# [ 5.12799993e-02  1.68299999e+01  6.25550002e-01  1.77649997e-01
#   3.30900005e-03  1.00984998e-01 -2.00000000e+00 -2.00000000e+00
#   3.33500004e+01 -2.00000000e+00  3.35599995e+01 -2.00000000e+00
#  -2.00000000e+00 -2.00000000e+00  1.99699998e-02 -2.00000000e+00
#  -2.00000000e+00  1.99099998e+01 -2.00000000e+00  1.01255002e-02
#  -2.00000000e+00 -2.00000000e+00  2.04049997e+01  1.19650002e+02
#  -2.00000000e+00 -2.00000000e+00  7.18649994e+02  2.59249992e+01
#  -2.00000000e+00 -2.00000000e+00 -2.00000000e+00]
# 31
# 31

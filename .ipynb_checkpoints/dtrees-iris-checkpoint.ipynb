# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from IPython.display import Image 
from pydot import graph_from_dot_data
import pandas as pd
import numpy as np
from io import StringIO

# %%
dataset = load_iris()
X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
y = pd.Categorical.from_codes(dataset.target, dataset.target_names)

# %%
y = pd.get_dummies(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
tree = DecisionTreeClassifier()

tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data, feature_names=dataset.feature_names)
(graph, ) = graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
def encode_tree(tree):
    print(tree.feature) 
    print(tree.threshold)
    print(len(tree.feature))
    print(len(tree.threshold))

encode_tree(tree.tree_)
# Out:
# [ 2 -2  2  3 -2 -2  3  2 -2  3 -2  2 -2 -2  2  0 -2 -2 -2]
# [ 2.44999999 -2.          4.75        1.65000004 -2.         -2.
#   1.75        4.95000005 -2.          1.55000001 -2.          5.45000005
#  -2.         -2.          4.85000014  5.95000005 -2.         -2.
#  -2.        ]
# 19
# 19
